# %%
import pandas as pd
import sqlite3 as sql
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
cnnct = sql.connect('D:\Programing\Programing_folder\Program Files\Real World projects of data science\Invoice Intelligence ML\data\inventory.db')
tables = pd.read_sql_query("select name from sqlite_master where  type ='table'",cnnct)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\maith\AppData\Local\Temp\ipykernel_2156\882524399.py:1: SyntaxWarning: invalid escape sequence '\P'
#   cnnct = sql.connect('D:\Programing\Programing_folder\Program Files\Real World projects of data science\Invoice Intelligence ML\data\inventory.db')

# %%
tables
# Out:
#               name
# 0        purchases
# 1  purchase_prices
# 2   vendor_invoice
# 3  begin_inventory
# 4    end_inventory

# %%
for table in tables['name']:
    print('Table Name:',table)
    df = pd.read_sql_query(f"select * from {table} limit 5",cnnct)
    display(df)
# Out:
# Table Name: purchases
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
vender_df = pd.read_sql_query('select * from vendor_invoice',cnnct)
vender_df.head(5)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47     None
# 1  2023-12-22  2024-02-21        15     140.55     8.57     None
# 2  2023-12-24  2024-02-16         5     106.60     4.61     None
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20     None

# %%
vender_df[['Quantity','Dollars','Freight']].corr()
# Out:
#           Quantity   Dollars   Freight
# Quantity  1.000000  0.963831  0.946550
# Dollars   0.963831  1.000000  0.985141
# Freight   0.946550  0.985141  1.000000

# %%
plt.figure(figsize=(4,2))
sns.heatmap(vender_df[['Quantity','Dollars','Freight']].corr(),annot=True)
plt.show()

plt.scatter(vender_df['Quantity'],vender_df['Freight'])
plt.scatter(vender_df['Dollars'],vender_df['Freight'])
plt.legend(['Quantity','Dollars'])
plt.ylabel('Freight')

plt.show()

# %%
vender_df['fright_per_unit']= vender_df['Freight']/vender_df['Quantity']

# %%
vender_df['fright_per_unit'].mean()
# Out:
# np.float64(0.0682416862660074)

# %%
low_Quant = vender_df['Quantity'].quantile(0.25)
high_Quant = vender_df['Quantity'].quantile(0.75)

# %%
high_Quant
# Out:
# np.float64(5100.5)

# %%
low_Quant
# Out:
# np.float64(83.0)

# %%
vender_df.loc[vender_df['Quantity']<low_Quant,'fright_per_unit'].mean()
# Out:
# np.float64(0.09489854253138316)

# %%
vender_df.loc[vender_df['Quantity']>high_Quant,'fright_per_unit'].mean()
# Out:
# np.float64(0.049077654690759046)

# %%
x = vender_df[['Dollars']]
y = vender_df['Freight']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42,shuffle=True)

# %%
x_train.shape
# Out:
# (4157, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
models = {
    'LinearRegression':LinearRegression(),
    'Ridge':Ridge(),
    'DecisionTreeRegressor':DecisionTreeRegressor(),
    'RandomForestRegressor':RandomForestRegressor()   
}

# %%
##Create a Function to Evaluate Model
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
results_list = []
for model_name, model in models.items():
    model.fit(x_train,y_train)

    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(model_name)
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model performance for Training set
# - Root Mean Squared Error: 124.7350
# - Mean Absolute Error: 24.8458
# - R2 Score: 0.9697
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 115.8765
# - Mean Absolute Error: 23.9057
# - R2 Score: 0.9729
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 124.7350
# - Mean Absolute Error: 24.8458
# - R2 Score: 0.9697
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 115.8765
# - Mean Absolute Error: 23.9057
# - R2 Score: 0.9729
# ...
#
#
# DecisionTreeRegressor
# Model performance for Training set
# - Root Mean Squared Error: 0.2353
# - Mean Absolute Error: 0.0140
# - R2 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 151.5634
# - Mean Absolute Error: 31.7447
# - R2 Score: 0.9536
# ...
#
#
# RandomForestRegressor
# Model performance for Training set
# ...

# %%
best_model = LinearRegression()
best_model.fit(x_train,y_train)
ypred = best_model.predict(x_test)
modelbest_test_mae, modelbest_test_rmse, modelbest_test_r2 = evaluate_model(y_test, ypred)
print("- Root Mean Squared Error: {:.4f}".format(modelbest_test_rmse))
print("- Mean Absolute Error: {:.4f}".format(modelbest_test_mae))
print("- R2 Score: {:.4f}".format(modelbest_test_r2))
# Out:
# - Root Mean Squared Error: 115.8765
# - Mean Absolute Error: 23.9057
# - R2 Score: 0.9729

# %%
test_daata =pd.DataFrame({
    'Dollars':[20000,30000]
})

# %%
plt.scatter(x_test ,y_test)
plt.plot(x_test,best_model.predict(x_test),color='red')

# %%
best_model.predict(test_daata)
# Out:
# array([105.1687808 , 155.49565728])
